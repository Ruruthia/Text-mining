# %%
import re
from itertools import product

import morfeusz2 as morfeusz2
import numpy as np
from gensim.models import KeyedVectors
from tqdm import tqdm

from List_4.utils import prepare_question, scaled_editdist, score_documents

# %%
word2vec = KeyedVectors.load("word2vec/word2vec_100_3_polish.bin")

# %%
with open("../List_2/outputs/indexed_contents.txt", "r") as f:
    content_lines = f.readlines()

with open("../List_2/outputs/indexed_titles.txt", "r") as f:
    titles_lines = f.readlines()

morph = morfeusz2.Morfeusz()

# %%
def get_definition_from_wiki(content):
    i = 1
    sents = re.split(r'(?<=[^A-Z].[.?]) +(?=[A-Z])', content)
    definition = str(sents[0])
    while len(definition) < 20 and len(sents) > i + 1:
        i+=1
        definition += str(sents[i])
    return definition

def get_definition_from_question(question):
    definition = []
    beginnings = ["Co oznacza", "Co po polsku oznacza", "Jak miał na imię", "Jak miała na imię", "Jak nazywa się", "Jak w", "Jak z", "Jak brzmi"]
    for beginning in beginnings:
        l = len(beginning)
        if question[:l] == beginning:
            definition = question[l:]
            break
    if len(definition) > 0:
        definition = definition.split()
        definition = [w.lower() for w in definition if not ("oznacza" in w or "nazywa" in w)]
        definition = " ".join(definition)
    return definition

# %%
def preprocess_definition(definition, only_first = True):
    definition = definition.strip().strip('"').split()
    definition = [w for w in definition if len(w) > 1]
    current_idx = 0
    current_def = []
    analysis = morph.analyse(" ".join(definition))
    if only_first:
        for i, j, interp in analysis:
            if i == current_idx:
                current_def.append(interp[1].partition(":")[0])
                current_idx += 1
    else:
        for i, j, interp in analysis:
            current_def.append(interp[1].partition(":")[0])
    return " ".join(definition), current_def

def get_definiton_vector(definition):
    vector = np.zeros(100)
    i = 1e-7
    for word in set(definition):
        try:
            vector += word2vec[word.lower()]
            i += 1
        except:
            continue
    return vector/i

# %%
def find_similar_definitions(definition, definition_vectors):
    target_vector = get_definiton_vector(definition)
    norm_target = np.sqrt((target_vector**2).sum())
    norm_features = np.sqrt((definition_vectors**2).sum(axis = 1))
    prod = target_vector @ definition_vectors.T
    scores = prod/(norm_target * norm_features + 1e-7)
    return scores.argsort()[::-1]

def answer(definition, titles_lines, definition_vectors):
    definition = preprocess_definition(definition)[1]
    print(definition)
    candidates = find_similar_definitions(definition, definition_vectors)[:30]
    for idx in candidates:
        title = titles_lines[idx].lower()
        _, res_tokens = prepare_question(title, morph)
        for t1, t2 in product(res_tokens, definition):
            if scaled_editdist(t1, t2) <= 0.4:
                break
        else:
            paren_index = title.find('(')
            if paren_index != -1:
                title = title[:paren_index]
            return title
    return "Nie znam odpowiedzi"

# %%
definition_vectors = np.zeros((len(content_lines), 100))
for i in tqdm(range(len(content_lines))):
    current_def = preprocess_definition(get_definition_from_wiki(content_lines[i]))
    definition_vectors[i, :] = get_definiton_vector(current_def[1])
# Out:
# 100%|██████████| 1208362/1208362 [05:19<00:00, 3777.32it/s]

# %%
similar = find_similar_definitions(preprocess_definition("szybki obrót wykonywany na palcach jednej nogi")[1], definition_vectors)[:10]
for title in similar:
    print(titles_lines[title].strip())
# Out:
# Waga (ćwiczenie gimnastyczne)
# Komendy i polecenia w Taekwondo
# Brachydaktylia
# Kołowrót (ćwiczenie gimnastyczne)
# Drążek skrętny
# Japonki
# Gilotyna
# Pas woltyżerski
# Ektrodaktylia
# Kulociąg

# %%
# 16/189
with open('../List_2/data/pytania.txt', 'r') as questions:
    with open('t3_odpowiedzi_tylko_wektory.txt', 'w') as f_out:
        line = questions.readline()
        while line:
            definition = get_definition_from_question(line.strip()[:-1])
            if len(definition) > 0:
                print(definition)
                a = answer(definition, titles_lines, definition_vectors)
                print(a)
                f_out.write(a.strip()+' \n')
            else:
                f_out.write("Nie o definicję" +' \n')
            line = questions.readline()
# Out:
# pierwsza litera alfabetu greckiego
# ['pierwsza', 'litera', 'alfabet', 'grecki']
# alfa
#
# dowolny odcinek łączący dwa punkty okręgu
# ['dowolny', 'odcinek', 'łączyć', 'dwa', 'punkt', 'okręg']
# cięciwa
#
# pierwiastek o symbolu bq
# ['pierwiastek', 'symbol', 'bq']
# skandowce
#
# wypukła albo wklęsła powierzchnia cieczy w pobliżu ścianek naczynia
# ['wypukły', 'albo', 'wklęsły', 'powierzchni', 'ciecz', 'pobliże', 'ścianka', 'naczynie']
# szalka petriego
#
# ulubione powiedzonko klucznika horeszków gerwazego
# ['ulubić', 'powiedzonko', 'klucznik', 'horeszków', 'Gerwazy']
# zagłoba
#
# wzgórze w paryżu na którym wybudowano bazylikę sacré-cœur
# ['wzgórze', 'Paryż', 'na', 'który', 'wybudować', 'bazylika', 'sacré', '-', 'cœur']
# tal-qadi
#
# greckiego się założenie wymagające sprawdzenia
# ['grecki', 'się', 'założenie', 'wymagający', 'sprawdzić']
# metoda intuicyjna
#
# trucizna przyrządzona z korzenia szaleju
# ['trucizna', 'przyrządzić', 'korzeń', 'szalej']
# haggis
#
# stolica kuby
# ['stolica', 'kub']
# jauja
#
# agent brytyjskiego wywiadu, bohater powieści iana fleminga
# ['agent', 'brytyjski', 'wywiad', ',', 'bohater', 'powieść', 'iana', 'Fleming']
# james bond
#
# przyrząd do palenia i górny kieł dzika
# ['przyrząd', 'do', 'palenie', 'górny', 'kieł', 'dzik']
# osęka wędkarska
#
# potomek osadników portugalskich bądź hiszpańskich w ameryce południowej
# ['potomek', 'osadnik', 'portugalski', 'bądź', 'hiszpański', 'Ameryka', 'południowy']
# iberoameryka
#
# tradycyjna żydowska czapka
# ['tradycyjny', 'żydowski', 'czapka']
# czulent
#
# najwyższy szczyt beskidu sądeckiego
# ['wysoki', 'szczyt', 'Beskid', 'sądecki']
# radziejowa
#
# jednostka w lotnictwie licząca 2–3 eskadry
# ['jednostka', 'lotnictwo', 'liczyć', '2', '–', '3', 'eskadra']
# vi dywizjon bombowy lekki
#
# obchodzone 31 października święto w krajach anglosaskich
# ['obchodzić', '31', 'październik', 'święto', 'kraj', 'anglosaski']
# dzień rosji
#
# polski okręt bojowy, którym brał udział w ii wojnie światowej, a od 40 lat znajduje się w gdyni
# ['polski', 'okręt', 'bojowy', ',', 'który', 'brać', 'udział', 'ii', 'wojna', 'światowy', ',', 'od', '40', 'lato', 'znajdować', 'się', 'Gdynia']
# u-1233
#
# elektroda połączona z ujemnym biegunem źródła prądu
# ['elektroda', 'połączyć', 'ujemny', 'biegun', 'źródło', 'prąd']
# dipol
#
# wieś, w której adam mickiewicz osadził akcję „pana tadeusza”
# ['wieś', ',', 'który', 'Adam', 'Mickiewicz', 'osadzić', 'akcja', '„', 'pan', 'Tadeusz', '”']
# edmund bieńkowski
#
# prezydent ukrainy
# ['prezydent', 'ukraina']
# premierzy litwy
#
# rycerz okrągłego stołu pałający uczuciem do królowej ginewry, żony króla artura
# ['rycerz', 'okrągły', 'stół', 'pałający', 'uczucie', 'do', 'królowa', 'ginewry', ',', 'żona', 'król', 'Artur']
# olwen
#
# polski malarz xix-wieczny, autor cyklu rysunków „polonia”
# ['polski', 'malarz', 'XIX-wieczny', ',', 'autor', 'cykl', 'rysunki', '„', 'Polonia', '”']
# zbigniew rabsztyn
#
# łaciny się zmętnienie soczewki oka
# ['łacina', 'się', 'zmętnieć', 'soczewka', 'oko']
# rubeoza tęczówki
#
# szczególny sąd, przed którym odpowiadają premier, prezydent i ministrowie
# ['szczególny', 'sąd', ',', 'przed', 'który', 'odpowiadać', 'premier', ',', 'prezydent', 'minister']
# kalendarium pierwszego rządu donalda tuska
#
# mityczne zwierzę z jednym rogiem, symbol szczęścia i niewinności
# ['mityczny', 'zwierzyć', 'jeden', 'róg', ',', 'symbol', 'szczęście', 'niewinność']
# pięciopalczasta ręka eris
#
# wyobrażenie martwego jezusa spoczywającego na kolanach maryi
# ['wyobrażenie', 'martwy', 'Jezus', 'spoczywać', 'na', 'kolanin', 'Maryja']
# obraz matki bożej w trokach
#
# drewniana nadbudówka na dziobie bądź rufie dawnych żaglowców
# ['drewniany', 'nadbudówka', 'na', 'dziób', 'bądź', 'ruf', 'dawny', 'żaglowiec']
# gig
# aktor, który dwukrotnie wcielił się w postać barbarzyńcy conana
# ['aktor', ',', 'który', 'dwukrotnie', 'wcielić', 'się', 'postać', 'barbarzyńca', 'conana']
# flcl
#
# osada w której mieszkali lasse, bosse, anna i olaf w książce astrid lindgren
# ['osada', 'który', 'mieszkać', 'lasse', ',', 'Bosse', ',', 'Anna', 'Olaf', 'książka', 'astrid', 'Lindgren']
# kikki danielsson
#
# wirus wywołujący chorobę heine-medina
# ['wirus', 'wywoływać', 'choroba', 'Heine', '-', 'medina']
# półpasiec
#
# najwyższy masyw górski sudetów
# ['wysoki', 'masyw', 'górski', 'Sudety']
# kotoń
#
# litera alfabetu morse'a jako trzy kreski
# ['litera', 'alfabet', "morse'a", 'jako', 'trzy', 'kreska']
# tetragraf
#
# dowództwo marynarki wojennej w wielkiej brytanii
# ['dowództwo', 'marynarka', 'wojenny', 'wielki', 'brytania']
# royal navy
#
# wędzony ser owczy produkowany w tatrach
# ['wędzić', 'ser', 'owczy', 'produkować', 'Tatry']
# hushållsost
#
# postawa zwątpienia, utrata wiary w powodzenie sprawy
# ['postawa', 'zwątpić', ',', 'utrata', 'wiara', 'powodzić', 'sprawa']
# zaufanie
#
# drapieżnik z rodziny psowatych o dużych uszach żyjący na saharze
# ['drapieżnik', 'rodzina', 'psowaty', 'duży', 'ucho', 'żyć', 'na', 'Sahara']
# zajączek błotny
#
# niemieckiego się ościeżnica do której przymocowane są drzwi
# ['niemiecki', 'się', 'ościeżnica', 'do', 'który', 'przymocować', 'być', 'drzwi']
# orczyca
#
# największy bezbarwny szlifowany diament na świecie, wydobyty w 1849 r. i przekazany królowej wiktorii
# ['duży', 'bezbarwny', 'szlifować', 'diament', 'na', 'świat', ',', 'wydobyć', '1849', 'rok', '.', 'przekazać', 'królowa', 'wiktoria']
# caryca waz
#
# nauka o bakteriach, wirusach i innych mikroorganizmach
# ['nauka', 'bakteria', ',', 'wirus', 'inny', 'mikroorganizm']
# immunologia
#
# rodzina roślin, do której należą groch, fasola, łubin
# ['rodzina', 'roślina', ',', 'do', 'który', 'należeć', 'groch', ',', 'fasola', ',', 'łubin']
# gorczyca polna
#
# oficjalna forma, w jakiej zwracamy się do wiceministra
# ['oficjalny', 'forma', ',', 'jaki', 'zwracać', 'się', 'do', 'wiceminister']
# on
#
# lalka teatralna nakładana na dłoń i poruszana palcami aktora
# ['lalka', 'teatralny', 'nakładany', 'na', 'dłoń', 'poruszać', 'palec', 'aktor']
# pacynka
#
# rozrywkowa dzielnica paryża, położona na najwyższym wzgórzu
# ['rozrywkowy', 'dzielnica', 'Paryż', ',', 'położony', 'na', 'najwyższy', 'wzgórze']
# montmartre
#
# łaciny się ćwiczenie ortograficzne polegające na zapisywaniu tekstu
# ['łacina', 'się', 'ćwiczyć', 'ortograficzny', 'polegać', 'na', 'zapisywać', 'tekst']
# czas teraźniejszy
#
# francuskiego się oficjalne zaprzeczenie albo sprostowanie jakiejś wiadomości
# ['francuski', 'się', 'oficjalny', 'zaprzeczenie', 'albo', 'sprostowanie', 'jakiś', 'wiadomości']
# lista z villejuif
#
# francuskiego się czytanie nut głosem
# ['francuski', 'się', 'czytanie', 'nut', 'głos']
# mim
#
# dziewczynka z zielonego wzgórza
# ['dziewczynka', 'zielone', 'wzgórze']
# pagórek
# park romantyczny założony przez helenę radziwiłłową w 1776 r. niedaleko nieborowa
# ['park', 'romantyczny', 'założyć', 'przez', 'Helena', 'radziwiłłową', '1776', 'rok', '.', 'niedaleko', 'nieborowy']
# pałac w pobiednej
#
# cyrulik sewilski
# ['cyrulik', 'sewilski']
# figaro
#
# duży zbiornik do przewożenia paliwa
# ['duży', 'zbiornik', 'do', 'przewozić', 'paliwo']
# tendrzak
#
# autobus elektryczny zasilany z sieci zawieszonej nad drogą
# ['autobus', 'elektryczny', 'zasilać', 'sieć', 'zawiesić', 'nad', 'droga']
# przewód jezdny
#
# kąt między południkiem geograficznym a południkiem magnetycznym
# ['kąt', 'między', 'południk', 'geograficzny', 'południk', 'magnetyczny']
# azymut astronomiczny
#
# stolica gruzji
# ['stolica', 'Gruzja']
# kastamonu
#
# członek grupy monty python, grał w filmach rybka zwana wandą
# ['członek', 'grupa', 'monty', 'python', ',', 'grać', 'film', 'rybka', 'zwać', 'Wanda']
# czarno-czarni
#
# kanał łączący morze irlandzkie z morzem celtyckim
# ['kanał', 'łączyć', 'morze', 'irlandzki', 'morze', 'celtycki']
# cieśnina hudsona
#
# słowo sukurs
# ['słowo', 'sukurs']
# dde
#
# należące do skleroprotein białko będące podstawowym budulcem włosów i paznokci
# ['należeć', 'do', 'skleroproteina', 'białko', 'być', 'podstawowy', 'budulec', 'włos', 'paznokieć']
# żywicowanie
#
# reżyser filmu „bliskie spotkanie trzeciego stopnia”
# ['reżyser', 'film', '„', 'bliski', 'spotkanie', 'trzeci', 'stopień', '”']
# devadasu
#
# imię tytułowego bohatera, miłego stworzenia z innej planety, filmu spielberga
# ['imię', 'tytułowy', 'bohater', ',', 'miły', 'stworzyć', 'inny', 'planet', ',', 'film', 'Spielberg']
# popeye
#
# greki się trzyczęściowe malowidło albo rzeźba
# ['greka', 'się', 'trzyczęściowy', 'malowidło', 'albo', 'rzeźba']
# malarstwo tablicowe
#
# po staropolsku niewola u turków lub tatarów
# ['po', 'staropolski', 'niewola', 'turek', 'lub', 'tatar']
# ljutowid
#
# w brydżu karta o małej wartości
# ['brydż', 'karta', 'mała', 'wartość']
# preferans
#
# przedstawicielstwo watykanu przy rządzie jakiegoś państwa
# ['przedstawicielstwo', 'Watykan', 'przy', 'rząd', 'jakiś', 'państwo']
# misje dyplomatyczne ugandy
#
# najwyższe polskie odznaczenie, które w 2012 otrzymali jerzy buzek i norman davies
# ['wysoki', 'polski', 'odznaczyć', ',', 'który', '2012', 'otrzymać', 'Jerzy', 'Buzek', 'Norman', 'Davies']
# stanisław fiszer
# urządzenie do zmiany biegów w rowerze
# ['urządzić', 'do', 'zmiana', 'bieg', 'rower']
# nartorolki
#
# eiffel, konstruktor wieży w paryżu
# ['Eiffel', ',', 'konstruktor', 'wieża', 'Paryż']
# europa-center
#
# telegrafistka w „czterech pancernych”
# ['telegrafistka', '„', 'cztery', 'pancerny', '”']
# trzy lipy
#
# popularna na bliskim wschodzie fajka wodna
# ['popularny', 'na', 'bliski', 'wschód', 'fajka', 'wodny']
# latarnia morska cromer
#
# sporcie się nieprzepisowe zagranie, uderzenie itp.
# ['sport', 'się', 'nieprzepisowy', 'zagrać', ',', 'uderzenie', 'i_tym_podobne', '.']
# didi
#
# kniaź, bohater opery aleksandra borodina
# ['kniaź', ',', 'bohater', 'opera', 'Aleksandra', 'Borodin']
# dyndalski
#
# ośrodek hodowli koni
# ['ośrodek', 'hodowla', 'koń']
# stado ogierów książ
#
# polski malarz makowski
# ['polski', 'malarz', 'makowski']
# andrzej drożeński
#
# inaczej niezborność oka, wynikająca z niedoskonałości ukształtowania rogówki
# ['inaczej', 'niezborność', 'oko', ',', 'wynikać', 'niedoskonałość', 'ukształtowanie', 'rogówka']
# niebieskie twardówki
#
# żona hadesa, która część roku spędzała pod ziemią, a część na ziemi
# ['żona', 'Hades', ',', 'który', 'część', 'rok', 'spędzać', 'pod', 'ziemia', ',', 'część', 'na', 'ziemia']
# pałac w czarnym borze
#
# słowo werwolf, którym nazwano niemiecki plan dywersji podczas ii wojny światowej
# ['słowo', 'werwolf', ',', 'który', 'nazwać', 'niemiecki', 'plan', 'dywersja', 'podczas', 'ii', 'wojna', 'światowy']
# wunderwaffe
#
# podanie rozpoczynające mecz siatkówki
# ['podać', 'rozpoczynać', 'mecz', 'siatkówka']
# lista meczów reprezentacji andory w piłce nożnej mężczyzn
#
# wokulski
# ['Wokulski']
# rejent
#
# waga towaru wraz z opakowaniem
# ['waga', 'towar', 'wraz', 'opakować']
# kontener
# polak, który w 1896 r. skonstruował szybowiec zwany lotnią
# ['polak', ',', 'który', '1896', 'rok', '.', 'skonstruować', 'szybowiec', 'zwać', 'lotnia']
# tu-135
#
# najniższy stopień wojskowy
# ['niski', 'stopić', 'wojskowy']
# vojvoda
#
# liczba określająca stosunek długości obwodu okręgu do jego średnicy
# ['liczba', 'określać', 'stosunek', 'długość', 'obwód', 'okręg', 'do', 'on', 'średnica']
# szerokość połówkowa
#
# pytanie, na które nie trzeba udzielać odpowiedzi, bo jest powszechnie znana
# ['pytać', ',', 'na', 'który', 'nie', 'trzeba', 'udzielać', 'odpowiedź', ',', 'bo', 'być', 'powszechnia', 'znana']
# strategia stabilna ewolucyjnie
#
# francuskiego określamy okulary, które trzymają się tylko na nosie
# ['francuski', 'określać', 'okulary', ',', 'który', 'trzymać', 'się', 'tylko', 'na', 'nosio']
# styl grzbietowy
#
# matka matki i ciasto
# ['matka', 'matka', 'ciasto']
# savarin
#
# buddyzmie i hinduizmie się stan wyzwolenia od cierpień i pragnień, ostateczny cel każdego wierzącego
# ['buddyzm', 'hinduizm', 'się', 'stan', 'wyzwolenie', 'od', 'cierpienie', 'pragnienie', ',', 'ostateczny', 'cel', 'każdy', 'wierzący']
# oświecenie
# greki sport konny, jeździectwo
# ['greka', 'sport', 'konny', ',', 'jeździectwo']
# hiszpańska szkoła jazdy
#
# nazwa albumu do znaczków
# ['nazwa', 'album', 'do', 'znaczek']
# bar-do travel
#
# termin fair play
# ['termin', 'fair', 'play']
# fourball
#
# postulat mówiący, że w atomie nie ma dwóch elektronów które by miały identyczne wszystkie cztery liczby kwantowe
# ['postulat', 'mówić', ',', 'że', 'atom', 'nie', 'mieć', 'dwa', 'elektron', 'który', 'by', 'miał', 'identyczny', 'wszystek', 'cztery', 'liczba', 'kwantowy']
# kointegracja
#
# pismo sądowe zapewniające oskarżonemu bezpieczeństwo przyjazdu z zagranicy
# ['pismo', 'sądowy', 'zapewniający', 'oskarżyć', 'bezpieczeństwo', 'przyjazd', 'zagranica']
# pisarz
# bohaterka gier komputerowych z serii tomb raider
# ['bohaterka', 'gra', 'komputerowy', 'seria', 'tomb', 'raider']
# kitana
#
# prawdziwe nazwisko majora hubala
# ['prawdziwy', 'nazwisko', 'major', 'Hubala']
# ćwik
#
# rysunek złożony z przecinających się linii, umieszczany na banknotach
# ['rysunek', 'złożony', 'przecinać', 'się', 'linia', ',', 'umieszczać', 'na', 'banknot']
# kontretykieta
#
# makuszyński
# ['Makuszyński']
# miciński
#
# zagłębienie na powierzchni księżyca wywołane uderzeniem meteorytu
# ['zagłębić', 'na', 'powierzchnia', 'księżyc', 'wywołać', 'uderzyć', 'meteoryt']
# krater uderzeniowy
#
# na statku oficer zajmujący się sprawami gospodarczymi
# ['na', 'statek', 'oficer', 'zajmować', 'się', 'sprawa', 'gospodarczy']
# marynarka handlowa
#
# nauka zajmująca się badaniem herbów
# ['nauka', 'zajmować', 'się', 'badać', 'herb']
# batrachologia
#
# brat vincenta van gogha, który wspierał go finansowo
# ['brat', 'vincenta', 'van', 'Gogh', ',', 'który', 'wspierać', 'on', 'finansowo']
# nicholas v. riasanovsky
#
# stolica białorusi
# ['stolica', 'białorusy']
# kastamonu
#
# łaciński wyraz quasi
# ['łaciński', 'wyraz', 'quasi']
# prekluzja
#
# ostatnia litera w greckim alfabecie
# ['ostatni', 'litera', 'grecki', 'alfabet']
# dzeta
#
# che guevara
# ['che', 'Guevara']
# podemos
#
# połowa połówki
# ['połowa', 'połówka']
# półbajt
#
# brytyjska aktorka, która zagrała szefową wywiadu w serii filmów o bondzie
# ['brytyjski', 'aktorka', ',', 'który', 'zagrać', 'szefowa', 'wywiad', 'seria', 'film', 'Bonda']
# anthony daniels
#
# mitologii greckiej się bóg wiatru północnego
# ['mitologia', 'grecki', 'się', 'bóg', 'wiatr', 'północny']
# euros
#
# jadalnia dla załogi na statku
# ['jadalnia', 'dla', 'załoga', 'na', 'statek']
# olinowanie
#
# tradycyjny rosyjski zaprzęg z trzech koni w jednym rzędzie
# ['tradycyjny', 'rosyjski', 'zaprzęg', 'trzy', 'koń', 'jeden', 'rząd']
# cug
#
# generał rowecki ps. grot
# ['generał', 'Rowecki', 'Księga_Psalmów', '.', 'grot']
# 6 brygada powietrznodesantowa
#
# główny deptak zakopanego
# ['główny', 'deptak', 'zakopać']
# plac jagielloński w radomiu
#
# wiersz pozbawiony rymów
# ['wiersz', 'pozbawić', 'rym']
# poemat liryczny
#
# łaciński zwrot „ad exemplum”
# ['łaciński', 'zwrot', '„', 'Ada', 'exemplum', '”']
# pariagium
#
# syn arystokraty porzucony w dżungli i wychowywany przez małpy
# ['syn', 'arystokrata', 'porzucić', 'dżungla', 'wychowywać', 'przez', 'małpa']
# tōju nakae
#
# niemieckiego się palny sznur służący do inicjowania wybuchu na odległość
# ['niemiecki', 'się', 'palny', 'sznur', 'służący', 'do', 'inicjować', 'wybuch', 'na', 'odległość']
# bomba odłamkowa
#
# kolektywne gospodarstwo rolne w izraelu
# ['kolektywny', 'gospodarstwo', 'rolny', 'Izrael']
# kibuc
#
# pisarz, autora „dziennika pisanego nocą”
# ['pisarz', ',', 'autor', '„', 'dziennik', 'pisane', 'noc', '”']
# co u pana słychać?
#
# zakład zajmujący się wyprawianiem skór
# ['zakład', 'zajmować', 'się', 'wyprawiać', 'skóra']
# tkactwo
#
# niemcewicz
# ['Niemcewicz']
# koźmian
#
# witos
# ['Witos']
# korfanty
#
# konstrukcja zabezpieczająca konstrukcje mostu przed uderzeniami kry
# ['konstrukcja', 'zabezpieczać', 'konstrukcja', 'most', 'przed', 'uderzenie', 'kra']
# izbica
# most zwodzony w londynie, wybudowany w xix wieku
# ['most', 'zwodzić', 'Londyn', ',', 'wybudować', 'XIX', 'wiek']
# ratusz w lubsku
#
# kosmodrom w kazachstanie
# ['kosmodrom', 'Kazachstan']
# plesieck
#
# dzień odpoczynku obchodzony przez żydów
# ['dzień', 'odpoczynek', 'obchodzić', 'przez', 'żyd']
# midsommar
#
# detektyw, którego przygody po raz pierwszy zostały opisane w książce „studium w szkarłacie”
# ['detektyw', ',', 'który', 'przygoda', 'po', 'raz', 'pierwszy', 'zostać', 'opisać', 'książka', '„', 'studium', 'szkarłat', '”']
# tomek wśród łowców głów
#
# żona heraklesa
# ['żona', 'Herakles']
# kreuza
# lutosławski
# ['lutosławski']
# kurpiński
#
# niekonwencjonalna metoda leczenia polegająca na uciskaniu określonych punktów na ciele pacjenta
# ['niekonwencjonalny', 'metoda', 'leczyć', 'polegać', 'na', 'uciskać', 'określić', 'punkt', 'na', 'ciało', 'pacjent']
# socjoterapia
#
# kobieta we frygijskiej czapce, symbol francji
# ['kobieta', 'w', 'frygijski', 'czapka', ',', 'symbol', 'Francja']
# hennin
#
# łaciny przemianę materii
# ['łacina', 'przemiana', 'materia']
# chemia
#
# trzyminutowy okres walki w boksie zawodowym
# ['trzyminutowy', 'okres', 'walka', 'boks', 'zawodowy']
# amatorska liga mma
#
# „opus magnum”
# ['„', 'opus', 'magnum', '”']
# rewolwer astra 357
#
# piosenka śpiewana w celu uśpienia dziecka
# ['piosenka', 'śpiewać', 'cel', 'uśpieć', 'dziecko']
# kołysanka
#
# tajemnicza istota nieznanego pochodzenia, człowiek śniegu
# ['tajemniczy', 'istota', 'nieznany', 'pochodzenie', ',', 'człowiek', 'śnieg']
# widmo
# łaciny przedłużenie okresu ważności umowy albo odroczenie terminu realizacji zobowiązania
# ['łacina', 'przedłużenie', 'okres', 'ważność', 'umowy', 'albo', 'odroczyć', 'termin', 'realizacja', 'zobowiązanie']
# prolongata
#
# największy gatunek pingwina
# ['duży', 'gatunek', 'pingwin']
# skrzeczyk pręgowany
#
# ginął uczony lavoisier
# ['ginąć', 'uczony', 'Lavoisier']
# seduliusz szkot
#
# jednostka natężenia dźwięku równa 1/10 bela
# ['jednostka', 'natężenie', 'dźwięk', 'równy', '1', '/', '10', 'bela']
# ćwierćton
#
# instrument muzyczny i ogon cietrzewia
# ['instrument', 'muzyczny', 'ogon', 'cietrzew']
# dziób
# ojciec edypa
# ['ojciec', 'Edyp']
# pitteus
#
# pomnik przedstawiający posąg kobiety trzymającej płonącą pochodnię i tablicę z deklaracją niepodległości usa
# ['pomnik', 'przedstawiać', 'posąg', 'kobieta', 'trzymać', 'płonący', 'pochodnia', 'tablica', 'deklaracja', 'niepodległość', 'USA']
# krzyż milenijny w zagórzu
#
# abił się pierwszy pies w kosmosie
# ['abił', 'się', 'pierwszy', 'pies', 'kosmos']
# engine sentai go-onger
#
# mitologii egipskiej się opiekun zmarłych odprowadzający ich na sąd
# ['mitologia', 'egipski', 'się', 'opiekun', 'zmarły', 'odprowadzać', 'on', 'na', 'sąd']
# synowie przymierza
#
# polska aktorka o nazwisku jędrusik
# ['polski', 'aktorka', 'nazwisko', 'Jędrusik']
# rodowicz
#
# aktorka, która dwukrotnie wcieliła się w postać lary croft
# ['aktorka', ',', 'który', 'dwukrotnie', 'wcielić', 'się', 'postać', 'lary', 'croft']
# x
# plac w londynie, na którym znajduje się kolumna nelsona
# ['plac', 'Londyn', ',', 'na', 'który', 'znajdować', 'się', 'kolumna', 'nelson']
# fontanna z neptunem w gliwicach
#
# jednoczesny wystrzał z wielu karabinów lub armat
# ['jednoczesny', 'wystrzał', 'wiele', 'karabin', 'lub', 'armata']
# salwa
#
# miejsce, gdzie według apokalipsy św. jana ma odbyć się starcie sił dobra i zła
# ['miejsce', ',', 'gdzie', 'według', 'apokalipsa', 'świadek', '.', 'Jana', 'mieć', 'odbyć', 'się', 'zetrzeć', 'siła', 'dobra', 'zło']
# soul eater
#
# najlepszy uczeń w klasie albo szkole
# ['dobry', 'uczeń', 'klasa', 'albo', 'szkoła']
# kangur matematyczny
#
# nauka o ssakach
# ['nauka', 'ssak']
# patologia zwierząt
#
# pseudonim polskiego malarza samouka epifaniusza drowniaka
# ['pseudonim', 'polskie', 'malarz', 'samouk', 'Epifaniusz', 'drowniaka']
# zbigniew kresowaty
#
# największy stadion w polsce
# ['duży', 'stadion', 'Polska']
# waldstadion
#
# pajęczyca z pszczółki mai
# ['pajęczyca', 'pszczółka', 'maja']
# mai
#
# łacińskie słowo „vivat”
# ['łaciński', 'słowo', '„', 'vivat', '”']
# auctoritas
#
# ukochana wokulskiego
# ['ukochać', 'Wokulski']
# erato
# faraon z „faraona” bolesława prusa
# ['faraon', '„', 'faraon', '”', 'Bolesława', 'Prus']
# adolf
# francuskiego się pomieszczenie w teatrze, w którym widownia przebywa w trakcie przerwy
# ['francuski', 'się', 'pomieścić', 'teatr', ',', 'który', 'widownia', 'przebywać', 'trakt', 'przerwa']
# proscenium
#
# negatywna uchwała odnośnie działań rządu
# ['negatywny', 'uchwała', 'odnośnie', 'działanie', 'rząd']
# zasady budżetowe
#
# pęk kwiatów zawieszany na budynku na znak, że jego budowa jest na ukończeniu
# ['pęk', 'kwiat', 'zawieszać', 'na', 'budynek', 'na', 'znak', ',', 'że', 'on', 'budowa', 'być', 'na', 'ukończenie']
# ulica sukiennicza w nysie
#
# mecz tenisa, w którym grają pary mieszane
# ['mecz', 'tenis', ',', 'który', 'grać', 'par', 'mieszany']
# piłka meczowa
#
# elastyczna deska umożliwiająca wybicie przy skokach do wody
# ['elastyczny', 'deska', 'umożliwiać', 'wybić', 'przy', 'skok', 'do', 'woda']
# narty
#
# fachowiec od analizy pisma ręcznego
# ['fachowiec', 'od', 'analiza', 'pismo', 'ręczny']
# badania ankietowe
#
# polski okręt podwodny, który podczas ii wojny światowej zniszczył 15 okrętów nieprzyjaciela
# ['polski', 'okręt', 'podwodny', ',', 'który', 'podczas', 'ii', 'wojna', 'światowy', 'zniszczyć', '15', 'okręt', 'nieprzyjaciel']
# konwój ons-92
#
# dwuosobowy zespół instrumentalny albo śpiewacki
# ['dwuosobowy', 'zespół', 'instrumentalny', 'albo', 'śpiewacki']
# kwartet saksofonowy
#
# dziewczyna z albatrosa
# ['dziewczyna', 'albatros']
# guantanamera
#
# szybki obrót wykonywany na palcach jednej nogi
# ['szybka', 'obrót', 'wykonywać', 'na', 'palec', 'jeden', 'noga']
# waga
# podręcznik do podstawowej nauki czytania i pisania
# ['podręcznik', 'do', 'podstawowy', 'nauka', 'czytać', 'pisanie']
# elementarz
#
# zbiór wszystkich punktów płaszczyzny znajdujący się w jednakowej odległości od jednego punktu
# ['zbiór', 'wszyscy', 'punkt', 'płaszczyzna', 'znajdować', 'się', 'jednakowy', 'odległość', 'od', 'jeden', 'punkt']
# biegun koła wielkiego
#
# islamie się nieunikniony los, fatum
# ['islam', 'się', 'nieunikniony', 'los', ',', 'fatum']
# hajime aikawa
#
# dział matematyki zajmujący się figurami płaskimi
# ['dział', 'matematyka', 'zajmować', 'się', 'figura', 'płaski']
# teoria pierścieni
#
# konserwowanie mięsa przez nasycenie go saletrą i przyprawami
# ['konserwować', 'mięso', 'przez', 'nasycenie', 'on', 'saletra', 'przyprawa']
# purée
#
# wodny pająk budujący pod wodą tzw. dzwony
# ['wodny', 'pająk', 'budować', 'pod', 'woda', 'tak_zwany', '.', 'dzwony']
# fontanna
#
# córka bolesława pobożnego, żona władysława łokietka
# ['córka', 'Bolesława', 'pobożny', ',', 'żona', 'Władysława', 'łokietek']
# aleksandra cieszyńska
#
# odkrywca promieni x, röntgen
# ['odkrywca', 'promienić', 'X', ',', 'röntgen']
# 52p/harrington-abell
#
# usuwanie owłosienia w celach leczniczych lub kosmetycznych
# ['usuwać', 'owłosić', 'cela', 'leczniczy', 'lub', 'kosmetyczny']
# meflochina
#
# ptak składający najmniejsze jaja
# ['ptak', 'składać', 'mały', 'jaja']
# mięso drobiowe
#
# siostra lilli wenedy
# ['siostra', 'Lilla', 'wenedy']
# sigrun
#
# autorka książek „karlsson z dachu”, „bracia lwie serce”
# ['autorka', 'książka', '„', 'Karlsson', 'dach', '”', ',', '„', 'bracia', 'lew', 'serce', '”']
# sonet 47
# chorobliwy lęk przed śmiercią
# ['chorobliwy', 'lęk', 'przed', 'śmierć']
# algofobia
#
# podstępny lis z bajki marii konopnickiej o krasnoludkach i sierotce marysi
# ['podstępny', 'lis', 'bajka', 'Maria', 'konopnicki', 'krasnoludek', 'sierotka', 'Marysia']
# jaś i małgosia
# roczny plan przewidywanych wydatków i przychodów państwa
# ['roczny', 'plan', 'przewidywać', 'wydatek', 'przychod', 'państwo']
# procedura budżetowa gminy
#
# pies ali z elementarza
# ['pies', 'ali', 'elementarz']
# psy
#
# żeglarstwie się wiatr wiejący skośnie od rufy
# ['żeglarstwo', 'się', 'wiatr', 'wiać', 'skośnie', 'od', 'ruf']
# fordewind
#
# psychologii się umiejętność jasnego wyrażania własnej opinii
# ['psychologia', 'się', 'umiejętność', 'jasny', 'wyrażać', 'własny', 'opinia']
# intelektualista
#
# dział zoologii zajmujący się badaniem pajęczaków
# ['dział', 'zoologia', 'zajmować', 'się', 'badać', 'pajęczak']
# lepidopterologia
#
# wynagrodzenie żołnierza służby zasadniczej
# ['wynagrodzenie', 'żołnierz', 'służba', 'zasadniczy']
# żołd
#
# największa jaszczurka
# ['duży', 'jaszczurka']
# łusecznica hiszpańska
#
# żydowski cmentarz
# ['żydowski', 'cmentarz']
# Nie znam odpowiedzi
# komenda sędziego bokserskiego nakazująca zawodnikom odstąpienie od siebie
# ['komenda', 'sędzia', 'bokserski', 'nakazujący', 'zawodnik', 'odstąpić', 'od', 'siebie']
# prawo bosmana
#
# dawna polska srebrna moneta, warta dobrego żartu
# ['dawny', 'polski', 'srebrny', 'moneta', ',', 'warta', 'dobre', 'żart']
# donatywa
#
# skrót 4wd na samochodach
# ['skrót', '4wd', 'na', 'samochód']
# papamobile

# %%
def answer_mod(question, weights, threshold,  titles_lines, definition_vectors):
    yes_or_no = question.split()[0] == "Czy"
    definition = get_definition_from_question(question)
    if len(definition) > 0:
        candidates = find_similar_definitions(preprocess_definition(definition)[1], definition_vectors)[:50]
    else:
        candidates = []
    _, question = prepare_question(question, morph)
    question = [token.lower() for token in question if len(token) > 1]
    while question:
        query = ' '.join(q for q in question)
        results = score_documents(query, weights, morph, candidates)
        search_results = list(results.keys())[:10]
        search_scores = list(results.values())[:10]
        search_results = zip(search_results, search_scores)
        for result, score in search_results:
            if yes_or_no:
                if score / len(question) < threshold:
                    return "nie"
                else:
                    return "tak"
            title = titles_lines[result]
            _, res_tokens = prepare_question(title, morph)
            for t1, t2 in product(res_tokens, question):
                if scaled_editdist(t1, t2) <= 0.3:
                    break
            else:
                paren_index = title.find('(')
                if paren_index != -1:
                    title = title[:paren_index]
                return title
        # if answer not found, remove first token of query
        del question[0]
    return 'nie mam pojęcia, sorry \n'

# %%
# 86/1000
with open('../List_2/data/pytania.txt', 'r') as questions:
    with open('t3_odpowiedzi_mieszane.txt', 'w') as f_out:
        line = questions.readline()
        while line:
            a = answer_mod(line.strip()[:-1], weights=[1, 1, 0.3, 0.3, 2], threshold=0.75, titles_lines=titles_lines, definition_vectors=definition_vectors)
            print(a.strip())
            f_out.write(a.strip()+' \n')
            line = questions.readline()
# Out:
# Alfa
# Cięciwa
# Nelly Rawlison
# tak
# Śmierć Kliniczna
# Trynidad i Tobago
    with open('t3_odpowiedzi_mieszane_1.txt', 'w') as f_out:
        line = questions.readline()
        while line:
            a = answer_mod(line.strip()[:-1], weights=[-0.5, 3, -0.2, 2, 2], threshold=1.5, titles_lines=titles_lines, definition_vectors=definition_vectors)
            print(a.strip())
            f_out.write(a.strip()+' \n')
            line = questions.readline()
# Out:
# Alfa
# Cięciwa
# Nelly Rawlison
# tak
# Aleksiej Morozow
# Trynidad i Tobago
# Tomasz Czereśniak
# Arianizm
# tak
# The Cellar Door Sessions 1970
# Władca zwierząt
# Reduktor
# XXXIX Liceum Ogólnokształcące im. Lotnictwa Polskiego w Warszawie
# Dębowa Kłoda
# Wiadro
# Giuseppe Zamboni
# Sokolniccy herbu Nowina
# Nawanialnia
# tak
# Krwotok
# Początek
# Skąd przyszliśmy? Kim jesteśmy? Dokąd idziemy?
# Giovanni Bertuccio
# Feblik
# Równoleżnik
# Hermitage Plaza
# Normalizacja bazy danych
# Ontologia
# Pan Twardowski
# Marynata
# Coracora
# SMERSZ
# Zabytki w Pabianicach
# Gimnazjum nr 2 im. Królowej Zofii w Sanoku
# Dzielny pies Rusty
# tak
# Kobieta Pracująca
# Lucio Wagner
# Marcin Mroczek
# Staw Staszica
# Tragedia Makbeta
# Kurilsk
# Zadłużenie krajowe PRL
# Gwinea Bissau
# tak
# Worki powietrzne
# Krótki film o miłości
# Deontologia
# Gnieciuch
# Skałat
# Aleksy Falconieri
# Wykiwać klawisza
# tak
# Powiat Ostvorpommern
# Redukcja misyjna
# Kazimierz Badowski
# Ewa
# Barbie jako księżniczka i żebraczka
# Izokrates
# tak
# Tonaż
# tak
# Paolo Bertoli
# Coco Island
# Pepin II Akwitański
# Kirribilli House
# Pieczęć stanowa Hawajów
# Salomon Halpert
# Ireneusz Wójcicki
# Polaryzacja grupowa
# Emil
# Geografia Australii
# Mateusz Cygański
# Józef Rautenstrauch
# Stemma codicum
# Kremnica
# Asklepios
# Szulchan Aruch
# Adam Łopatka
# Laurent Gbagbo
# William Barker
# Gabriel von Eisenstein
# Motycz
# Ciecień
# BrzydUla
# Osoba
# Estoński Legion Lotniczy
# Pistolet MAG
# Gwiazdozbiór Liska
# Niewidzialna forteca
# Międzynarodowy Dzień Archiwów
# Robert William Thomson
# Digimon Adventure
# Sezon 2012/2013 w hokeju na lodzie
# Giulio Alberoni
# Antoine Bourdelle
# U-1005
# Tańczące sylwetki
# Livingstone
# Święty Pankracy
# Faza
# tak
# Down in the Groove
# Kanclerz wielki koronny
# Jan Oppeln-Bronikowski
# Wartość fenotypowa
# E=MC²
# tak
# Hades
# Konfederacja Narodów Kaukazu
# Susanna Clarke
# Astryda obodrycka
# Kąkolówka
# Świerzop
# Kraina palearktyczna
# Loro Kovaçi
# Mróz
# Polowanie na Czerwony Październik
# Bromba i inni
# Tadeusz Peiper
# Wuffingowie
# Kościół Najświętszego Serca Pana Jezusa w Kiszkowie
# Lampa szczelinowa
# Wojciech Remigian Prażmowski
# Rząd Bahamów
# Makaronizm
